# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('03-Pandas/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# # Columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df['tip_percentage'] = 100 * df['tip'] / df['total_bill']

# %%
df['tip_percentage'] = np.round(df['tip_percentage'],2)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
df['namee'] = 'bam' + str(df['tip'])
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68
#
#                                                namee
# 0  bam0      1.01\n1      1.66\n2      3.50\n3   ...
# 1  bam0      1.01\n1      1.66\n2      3.50\n3   ...
# 2  bam0      1.01\n1      1.66\n2      3.50\n3   ...
# 3  bam0      1.01\n1      1.66\n2      3.50\n3   ...
# 4  bam0      1.01\n1      1.66\n2      3.50\n3   ...

# %%
df = df.drop('namee', axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
df[(df['total_bill'] > 30) & (df['tip'] < 5)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4              9.50
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4             10.04
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3             14.77
# 112       38.07  4.00    Male     No  Sun  Dinner     3             12.69
# 167       31.71  4.50    Male     No  Sun  Dinner     4              7.93
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2             15.92
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2             16.45
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2             17.32
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4              8.66
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3             15.12
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2             20.27
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5              6.09
# 207       38.73  3.00    Male    Yes  Sat  Dinner     4              9.68
# 210       30.06  2.00    Male    Yes  Sat  Dinner     3             10.02
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4              7.54
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
#
#                 Payer Name         CC Number Payment ID  tip_percentage
# 56   James Christensen DDS   349793629453226    Sat8903            7.89
# 95           Aaron Bentley   180026611638690    Fri9628           11.77
# 102          Heather Cohen   379771118886604    Sat6240            5.64
# 112             Jeff Lopez  3572865915176463     Sun591           10.51
# 167         Michael Lawson  3566285921227119    Sun3719           14.19
# 173            Scott Perez  3577115550328507    Sun9335            9.98
# 175        Nathan Reynolds   370307040837149    Sun5109            9.45
# 179           Brian Bailey   346656312114848    Sun9851           10.25
# 180       James Hebert DDS      676168737648    Sun7544           10.62
# 182           Jose Parsons  4112207559459910    Sun2337            7.72
# 184            Stephen Cox  3547798222044029    Sun5140            7.40
# 187          David Barrett  4792882899700988    Sun9987            6.57
# 207          Ricky Ramirez   347817964484033    Sat4505            7.75
# 210          Shawn Mendoza    30184049218122    Sat8361            6.65
# 219           Shelby House      502097403252    Sat8863           10.25
# 237           Thomas Brown  4284722681265508    Sat2929            3.56
# 238         Kimberly Crane      676184013727    Sat9777           13.03

# %%
options = ['Sat','Sun']
df[df['day'].isin(options)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID  tip_percentage
# 0    Christy Cunningham  3560325168603410    Sun2959            5.94
# 1        Douglas Tucker  4478071379779230    Sun4608           16.05
# 2        Travis Walters  6011812112971322    Sun4458           16.66
# 3      Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4          Tonya Carter  4832732618637221    Sun2251           14.68
# ..                  ...               ...        ...             ...
# 238      Kimberly Crane      676184013727    Sat9777           13.03
# 239       Michael Avila  5296068606052842    Sat2657           20.39
# 240      Monica Sanders  3506806155565404    Sat1766            7.36
# 241          Keith Wong  6011891618747196    Sat3880            8.82
# 242        Dennis Dixon     4375220550950      Sat17            9.82
#
# [163 rows x 12 columns]

# %%
str(324243243)[-4:]
def last_four(num):
    return str(num)[-4:]

# %%
last_four(32424343)
# Out:
# '4343'

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage last_four
# 0    Christy Cunningham  3560325168603410    Sun2959            5.94      3410
# 1        Douglas Tucker  4478071379779230    Sun4608           16.05      9230
# 2        Travis Walters  6011812112971322    Sun4458           16.66      1322
# 3      Nathaniel Harris  4676137647685994    Sun5260           13.98      5994
# 4          Tonya Carter  4832732618637221    Sun2251           14.68      7221
# ..                  ...               ...        ...             ...       ...
# 239       Michael Avila  5296068606052842    Sat2657           20.39      2842
# 240      Monica Sanders  3506806155565404    Sat1766            7.36      5404
# 241          Keith Wong  6011891618747196    Sat3880            8.82      7196
# 242        Dennis Dixon     4375220550950      Sat17            9.82      0950
# 243     Michelle Hardin  3511451626698139    Thur672           15.97      8139
#
# [244 rows x 13 columns]

# %%
def quality(total_bill, tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
df['quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'],df['tip']), axis=1)

# %%
df['quality'] =
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 51        10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2              7.16
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2              4.80
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4              5.79
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2              6.71
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
#
#             Payer Name         CC Number Payment ID  tip_percentage last_four  \
# 51      Jessica Ibarra     4999759463713    Sun4474           25.27      3713
# 67       Tiffany Brock  4359488526995267    Sat3455           32.57      5267
# 93      Natalie Nguyen  5181236182893396    Fri6963           26.35      3396
# 109    Amanda Anderson   375638820334211    Sat2614           27.95      4211
# 149     Daniel Robbins  4823139288341889   Thur6321           26.63      1889
# 172        Larry White    30432617123103    Sun9209           71.03      3103
# 178       Melanie Gray     4211808859168    Sun4598           41.67      9168
# 183  Dr. Michael James     4718501859162    Sun6059           28.05      9162
# 221     Leslie Kaufman   379437981958785    Fri7511           25.93      8785
# 232       James Taylor  6011482917327995    Sat2124           29.20      7995
#
#       quality
# 51   Generous
# 67   Generous
# 93   Generous
# 109  Generous
# 149  Generous
# 172  Generous
# 178  Generous
# 183  Generous
# 221  Generous
# 232  Generous
